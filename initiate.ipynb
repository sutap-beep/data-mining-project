# %%
# %%writefile .github/workflows/ci_cd_pipeline.yml
# name: CI/CD Pipeline
# on:
#     push:
#         branches:
#             -main
#         pull_request:
#             branches:
#                 -main
# jobs:
#     build:
#         runs-on: ubuntu-latest
#
#         steps:
#             - name: checkout code
#               uses: actions/checkout@v3
#             - name: Set up Python
#               uses: actions/setup-python@v3
#               with:
#                 python-version: '3/x'
#             - name: Install dependencies
#               run:  |
#                 python -m pip install --upgrade pip
#                 pip install -r requirements.txt
#             - name: Run tests
#               run: pytest tests/ -v
#             - name: Deploy (Simulation)
#               run: echo "Simulated deployment"
# Out:
# Writing .github/workflows/ci_cd_pipeline.yml
